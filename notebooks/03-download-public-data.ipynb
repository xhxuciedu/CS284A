# %% [markdown]
# ## Download public data and perform simple data analysis

# %% [markdown]
# 1. Google GSE41265, which will show you a link to GEO database
#
# 2. Or follow this [link](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE41265) to jump directly to the GEO page for this data. Scroll down to the bottom in supplemental material. And download the link for the table called GSE41265_allGenesTPM.txt.gz.
#
# 3. We also need the link to the metadata. It is <a href="ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE41nnn/GSE41265/matrix/"> Series Matrix</a>. Download the file called GSE41265_series_matrix.txt.gz.
#
# 4. The data is described in this reference
# * [Single-cell transcriptomics reveals bimodality in expression and splicing in immune cells](http://www.ncbi.nlm.nih.gov/pubmed/23685454) Shalek and Satija, *et al*.,  *Nature*, 2013

# %% [markdown]
# ## Reading in the data file
#
# To read the gene expression matrix, we'll use "`pandas`" a Python package for "Panel Data Analysis" (as in panels of data), which is a fantastic library for working with dataframes, and is Python's answer to R's dataframes. We'll take this opportunity to import ALL of the python libaries that we'll use today.
#
# We'll be using several additional libraries in Python:
#
# 3. [`matplotlib`](http://matplotlib.org/) - This is the base plotting library in Python.
# 1. [`numpy`](http://www.numpy.org/) - (pronounced "num-pie") which is basis for most scientific packages. It's basically a nice-looking Python interface to C code. It's very fast.
# 2. [`pandas`](http://pandas.pydata.org) - This is the "DataFrames in Python." (like R's nice dataframes) They're a super convenient form that's based on `numpy` so they're fast. And you can do convenient things like calculate mea n and variance very easily.
# 4. [`scipy`](http://www.scipy.org/) - (pronounced "sigh-pie") "Scientific Python" - Contains statistical methods and calculations
# 4. [`seaborn`](http://web.stanford.edu/~mwaskom/software/seaborn/index.html) - Statistical plotting library. To be completely honest, R's plotting and graphics capabilities are much better than Python's. However, Python is a really nice langauge to learn and use, it's very memory efficient, can be parallized well, and has a very robust machine learning library, `scikit-learn`, which has a very nice and consistent interface. So this is Python's answer to `ggplot2` (very popular R library for plotting) to try and make plotting in Python nicer looking and to make statistical plots easier to do.

# %%
# Python plotting library
import matplotlib.pyplot as plt
# This is necessary to show the plotted figures inside the notebook -- "inline" with the notebook cells
# %matplotlib inline

# Numerical python library (pronounced "num-pie")
import numpy as np

# Dataframes in Python
import pandas as pd

# Statistical plotting library we'll use
import seaborn as sns

# %% [markdown]
# We'll read in the data using `pandas` and look at the first 5 rows of the dataframe with the dataframe-specific function `.head()`. Whenever I read a new table or modify a dataframe, I **ALWAYS** look at it to make sure it was correctly imported and read in, and I want you to get into the same habit.

# %%
# Read the data table
# You may need to change the path to the file (what's in quotes below) relative 
# to where you downloaded the file and where this notebook is
shalek2013_expression = pd.read_table('data/GSE41265_allGenesTPM.txt.gz', 
                               
                                     # Sets the first (Python starts counting from 0 not 1) column as the row names
                                      index_col=0, 

                                     # Tells pandas to decompress the gzipped file
                                      compression='gzip')


print(shalek2013_expression.shape)
shalek2013_expression.head()
# Out:
# (27723, 21)
#                  S1        S2          S3        S4        S5        S6  \
# GENE
# XKR4       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# AB338584   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# B3GAT2     0.000000  0.000000    0.023441  0.000000  0.000000  0.029378
# NPL       72.008590  0.000000  128.062012  0.095082  0.000000  0.000000
# T2         0.109249  0.172009    0.000000  0.000000  0.182703  0.076012
#
#                   S7          S8        S9       S10  ...       S12       S13  \
# GENE                                                  ...
# XKR4        0.000000    0.000000  0.000000  0.000000  ...  0.000000  0.000000
# AB338584    0.000000    0.000000  0.000000  0.000000  ...  0.000000  0.000000
# B3GAT2      0.000000    0.055452  0.000000  0.029448  ...  0.000000  0.000000
# NPL       112.310234  104.329122  0.119230  0.000000  ...  0.000000  0.116802
# T2          0.078698    0.000000  0.093698  0.076583  ...  0.693459  0.010137
#
#                S14       S15       S16       S17        S18        P1  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# B3GAT2    0.031654  0.000000  0.000000  0.000000  42.150208  0.680327
# NPL       0.104200  0.106188  0.229197  0.110582   0.000000  7.109356
# T2        0.081936  0.000000  0.000000  0.086879   0.068174  0.062063
#
#                 P2         P3
# GENE
# XKR4      0.019906   0.000000
# AB338584  0.000000   0.000000
# B3GAT2    0.022996   0.110236
# NPL       6.727028  14.525447
# T2        0.000000   0.050605
#
# [5 rows x 21 columns]

# %% [markdown]
# So we have 21 columns but looks like here `pandas` by default is showing a maximum of 20 so let's change the setting so we can see ALL of the samples instead of just skipping single cell 11 (**S11**). Let's change to 50 for good measure.

# %%
pd.options.display.max_columns = 50
pd.options.display.max_rows = 50
shalek2013_expression.head()
# Out:
#                  S1        S2          S3        S4        S5        S6  \
# GENE
# XKR4       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# AB338584   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# B3GAT2     0.000000  0.000000    0.023441  0.000000  0.000000  0.029378
# NPL       72.008590  0.000000  128.062012  0.095082  0.000000  0.000000
# T2         0.109249  0.172009    0.000000  0.000000  0.182703  0.076012
#
#                   S7          S8        S9       S10       S11       S12  \
# GENE
# XKR4        0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584    0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2      0.000000    0.055452  0.000000  0.029448  0.024137  0.000000
# NPL       112.310234  104.329122  0.119230  0.000000  0.000000  0.000000
# T2          0.078698    0.000000  0.093698  0.076583  0.000000  0.693459
#
#                S13       S14       S15       S16       S17        S18  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# B3GAT2    0.000000  0.031654  0.000000  0.000000  0.000000  42.150208
# NPL       0.116802  0.104200  0.106188  0.229197  0.110582   0.000000
# T2        0.010137  0.081936  0.000000  0.000000  0.086879   0.068174
#
#                 P1        P2         P3
# GENE
# XKR4      0.000000  0.019906   0.000000
# AB338584  0.000000  0.000000   0.000000
# B3GAT2    0.680327  0.022996   0.110236
# NPL       7.109356  6.727028  14.525447
# T2        0.062063  0.000000   0.050605

# %% [markdown]
# Now we can see all the samples!
#
# Let's take a look at the full size of the matrix with `.shape`:

# %%
shalek2013_expression.shape
# Out:
# (27723, 21)

# %% [markdown]
# ## Reading in the metadata

# %%
shalek2013_metadata = pd.read_table('data/GSE41265_series_matrix.txt.gz',
                                    compression = 'gzip',
                                    skiprows=33, 
                                    index_col=0)
print(shalek2013_metadata.shape)
shalek2013_metadata
# Out:
# (48, 24)
#                                                                         GSM1012777  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S1
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012777
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012778  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S2
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012778
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012779  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S3
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012779
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012780  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S4
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012780
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012781  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S5
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012781
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012782  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S6
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012782
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012783  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S7
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012783
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012784  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S8
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012784
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012785  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                             S9
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012785
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012786  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                            S10
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012786
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012787  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               May 19 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1                                                    NaN
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                            S11
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012787
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1012788  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Oct 01 2012
# !Sample_last_update_date                                               Dec 23 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# ...
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1                     cDNA synthesis and amplification:
# !Sample_extract_protocol_ch1     We used the SMARTer Ultra Low RNA Kit (Clontec...
# !Sample_extract_protocol_ch1     We created Illumina sequencing libraries from ...
# !Sample_extract_protocol_ch1               cDNA shearing and library construction:
# !Sample_extract_protocol_ch1     We added the purification buffer (Clontech) to...
# !Sample_extract_protocol_ch1     We prepared indexed paired-end libraries for I...
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                        S21_10k
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1012797
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1110889  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Mar 29 2013
# !Sample_last_update_date                                               May 21 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1      protocol: molecular barcodes (MB) using a modi...
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1     cDNA from each sample was prepared using the S...
# !Sample_extract_protocol_ch1     For the three molecular barcode (MB) libraries...
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                            MB1
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1110889
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1110890  \
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Mar 29 2013
# !Sample_last_update_date                                               May 21 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1      protocol: molecular barcodes (MB) using a modi...
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1     cDNA from each sample was prepared using the S...
# !Sample_extract_protocol_ch1     For the three molecular barcode (MB) libraries...
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                            MB2
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1110890
# !series_matrix_table_end                                                       NaN
#
#                                                                         GSM1110891
# !Sample_geo_accession
# !Sample_status                                               Public on May 19 2013
# !Sample_submission_date                                                Mar 29 2013
# !Sample_last_update_date                                               May 21 2013
# !Sample_type                                                                   SRA
# !Sample_channel_count                                                            1
# !Sample_source_name_ch1                                         BMDC (4h LPS stim)
# !Sample_organism_ch1                                                  Mus musculus
# !Sample_characteristics_ch1                                        strain: C57BL/6
# !Sample_characteristics_ch1      cell type: Bone Marrow-derived Dendritic Cell ...
# !Sample_characteristics_ch1                             treatment: LPS-stimulation
# !Sample_characteristics_ch1                                     cell count: 1 cell
# !Sample_characteristics_ch1      protocol: molecular barcodes (MB) using a modi...
# !Sample_growth_protocol_ch1      Cells were cultured and stimulated with LPS as...
# !Sample_molecule_ch1                                                     polyA RNA
# !Sample_extract_protocol_ch1     cDNA from each sample was prepared using the S...
# !Sample_extract_protocol_ch1     For the three molecular barcode (MB) libraries...
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_extract_protocol_ch1                                                   NaN
# !Sample_taxid_ch1                                                            10090
# !Sample_description                                                            MB3
# !Sample_data_processing          We created a Bowtie index based on the UCSC kn...
# !Sample_data_processing          Next, we ran RSEM v1.11 with default parameter...
# !Sample_data_processing                                          Genome_build: mm9
# !Sample_data_processing          Supplementary_files_format_and_content: File a...
# !Sample_platform_id                                                       GPL13112
# !Sample_contact_name                                                 Rahul,,Satija
# !Sample_contact_email                                         rsatija@nygenome.org
# !Sample_contact_phone                                                   6177022468
# !Sample_contact_laboratory                                              Satija Lab
# !Sample_contact_institute                                   New York Genome Center
# !Sample_contact_address                                 101 Avenue of the Americas
# !Sample_contact_city                                                 New York City
# !Sample_contact_state                                                           NY
# !Sample_contact_zip/postal_code                                              10013
# !Sample_contact_country                                                        USA
# !Sample_data_row_count                                                           0
# !Sample_instrument_model                                       Illumina HiSeq 2000
# !Sample_library_selection                                                     cDNA
# !Sample_library_source                                              transcriptomic
# !Sample_library_strategy                                                   RNA-Seq
# !Sample_relation                 SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# !Sample_relation                 BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# !Sample_supplementary_file_1                                                  NONE
# !series_matrix_table_begin                                                     NaN
# ID_REF                                                                  GSM1110891
# !series_matrix_table_end                                                       NaN

# %% [markdown]
# Let's transpose this matrix so the samples are the rows, and the features are the columns. We'll do that with `.T`

# %%
shalek2013_metadata = shalek2013_metadata.T
shalek2013_metadata
# Out:
# !Sample_geo_accession         !Sample_status !Sample_submission_date  \
# GSM1012777             Public on May 19 2013             Oct 01 2012
# GSM1012778             Public on May 19 2013             Oct 01 2012
# GSM1012779             Public on May 19 2013             Oct 01 2012
# GSM1012780             Public on May 19 2013             Oct 01 2012
# GSM1012781             Public on May 19 2013             Oct 01 2012
# GSM1012782             Public on May 19 2013             Oct 01 2012
# GSM1012783             Public on May 19 2013             Oct 01 2012
# GSM1012784             Public on May 19 2013             Oct 01 2012
# GSM1012785             Public on May 19 2013             Oct 01 2012
# GSM1012786             Public on May 19 2013             Oct 01 2012
# GSM1012787             Public on May 19 2013             Oct 01 2012
# GSM1012788             Public on May 19 2013             Oct 01 2012
# GSM1012789             Public on May 19 2013             Oct 01 2012
# GSM1012790             Public on May 19 2013             Oct 01 2012
# GSM1012791             Public on May 19 2013             Oct 01 2012
# GSM1012792             Public on May 19 2013             Oct 01 2012
# GSM1012793             Public on May 19 2013             Oct 01 2012
# GSM1012794             Public on May 19 2013             Oct 01 2012
# GSM1012795             Public on May 19 2013             Oct 01 2012
# GSM1012796             Public on May 19 2013             Oct 01 2012
# GSM1012797             Public on May 19 2013             Oct 01 2012
# GSM1110889             Public on May 19 2013             Mar 29 2013
# GSM1110890             Public on May 19 2013             Mar 29 2013
# GSM1110891             Public on May 19 2013             Mar 29 2013
#
# !Sample_geo_accession !Sample_last_update_date !Sample_type  \
# GSM1012777                         May 19 2013          SRA
# GSM1012778                         May 19 2013          SRA
# GSM1012779                         May 19 2013          SRA
# GSM1012780                         May 19 2013          SRA
# GSM1012781                         May 19 2013          SRA
# GSM1012782                         May 19 2013          SRA
# GSM1012783                         May 19 2013          SRA
# GSM1012784                         May 19 2013          SRA
# GSM1012785                         May 19 2013          SRA
# GSM1012786                         May 19 2013          SRA
# GSM1012787                         May 19 2013          SRA
# GSM1012788                         Dec 23 2013          SRA
# GSM1012789                         Dec 23 2013          SRA
# GSM1012790                         Dec 23 2013          SRA
# GSM1012791                         Dec 23 2013          SRA
# GSM1012792                         Dec 23 2013          SRA
# GSM1012793                         Dec 23 2013          SRA
# GSM1012794                         Dec 23 2013          SRA
# GSM1012795                         May 19 2013          SRA
# GSM1012796                         May 19 2013          SRA
# GSM1012797                         May 19 2013          SRA
# GSM1110889                         May 21 2013          SRA
# GSM1110890                         May 21 2013          SRA
# GSM1110891                         May 21 2013          SRA
#
# !Sample_geo_accession !Sample_channel_count !Sample_source_name_ch1  \
# GSM1012777                                1      BMDC (4h LPS stim)
# GSM1012778                                1      BMDC (4h LPS stim)
# GSM1012779                                1      BMDC (4h LPS stim)
# GSM1012780                                1      BMDC (4h LPS stim)
# GSM1012781                                1      BMDC (4h LPS stim)
# GSM1012782                                1      BMDC (4h LPS stim)
# GSM1012783                                1      BMDC (4h LPS stim)
# GSM1012784                                1      BMDC (4h LPS stim)
# GSM1012785                                1      BMDC (4h LPS stim)
# GSM1012786                                1      BMDC (4h LPS stim)
# GSM1012787                                1      BMDC (4h LPS stim)
# GSM1012788                                1      BMDC (4h LPS stim)
# GSM1012789                                1      BMDC (4h LPS stim)
# GSM1012790                                1      BMDC (4h LPS stim)
# GSM1012791                                1      BMDC (4h LPS stim)
# GSM1012792                                1      BMDC (4h LPS stim)
# GSM1012793                                1      BMDC (4h LPS stim)
# GSM1012794                                1      BMDC (4h LPS stim)
# GSM1012795                                1      BMDC (4h LPS stim)
# GSM1012796                                1      BMDC (4h LPS stim)
# GSM1012797                                1      BMDC (4h LPS stim)
# GSM1110889                                1      BMDC (4h LPS stim)
# GSM1110890                                1      BMDC (4h LPS stim)
# GSM1110891                                1      BMDC (4h LPS stim)
#
# !Sample_geo_accession !Sample_organism_ch1 !Sample_characteristics_ch1  \
# GSM1012777                    Mus musculus             strain: C57BL/6
# GSM1012778                    Mus musculus             strain: C57BL/6
# GSM1012779                    Mus musculus             strain: C57BL/6
# GSM1012780                    Mus musculus             strain: C57BL/6
# GSM1012781                    Mus musculus             strain: C57BL/6
# GSM1012782                    Mus musculus             strain: C57BL/6
# GSM1012783                    Mus musculus             strain: C57BL/6
# GSM1012784                    Mus musculus             strain: C57BL/6
# GSM1012785                    Mus musculus             strain: C57BL/6
# GSM1012786                    Mus musculus             strain: C57BL/6
# GSM1012787                    Mus musculus             strain: C57BL/6
# GSM1012788                    Mus musculus             strain: C57BL/6
# GSM1012789                    Mus musculus             strain: C57BL/6
# GSM1012790                    Mus musculus             strain: C57BL/6
# GSM1012791                    Mus musculus             strain: C57BL/6
# GSM1012792                    Mus musculus             strain: C57BL/6
# GSM1012793                    Mus musculus             strain: C57BL/6
# GSM1012794                    Mus musculus             strain: C57BL/6
# GSM1012795                    Mus musculus             strain: C57BL/6
# GSM1012796                    Mus musculus             strain: C57BL/6
# GSM1012797                    Mus musculus             strain: C57BL/6
# GSM1110889                    Mus musculus             strain: C57BL/6
# GSM1110890                    Mus musculus             strain: C57BL/6
# GSM1110891                    Mus musculus             strain: C57BL/6
#
# !Sample_geo_accession                        !Sample_characteristics_ch1  \
# GSM1012777             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012778             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012779             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012780             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012781             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012782             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012783             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012784             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012785             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012786             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012787             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012788             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012789             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012790             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012791             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012792             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012793             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012794             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012795             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012796             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012797             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1110889             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1110890             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1110891             cell type: Bone Marrow-derived Dendritic Cell ...
#
# !Sample_geo_accession !Sample_characteristics_ch1 !Sample_characteristics_ch1  \
# GSM1012777             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012778             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012779             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012780             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012781             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012782             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012783             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012784             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012785             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012786             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012787             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012788             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012789             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012790             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012791             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012792             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012793             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012794             treatment: LPS-stimulation          cell count: 1 cell
# GSM1012795             treatment: LPS-stimulation    cell count: 10,000 cells
# GSM1012796             treatment: LPS-stimulation    cell count: 10,000 cells
# GSM1012797             treatment: LPS-stimulation    cell count: 10,000 cells
# GSM1110889             treatment: LPS-stimulation          cell count: 1 cell
# GSM1110890             treatment: LPS-stimulation          cell count: 1 cell
# GSM1110891             treatment: LPS-stimulation          cell count: 1 cell
#
# !Sample_geo_accession                        !Sample_characteristics_ch1  \
# GSM1012777                                                           NaN
# GSM1012778                                                           NaN
# GSM1012779                                                           NaN
# GSM1012780                                                           NaN
# GSM1012781                                                           NaN
# GSM1012782                                                           NaN
# GSM1012783                                                           NaN
# GSM1012784                                                           NaN
# GSM1012785                                                           NaN
# GSM1012786                                                           NaN
# GSM1012787                                                           NaN
# GSM1012788                                                           NaN
# GSM1012789                                                           NaN
# GSM1012790                                                           NaN
# GSM1012791                                                           NaN
# GSM1012792                                                           NaN
# GSM1012793                                                           NaN
# GSM1012794                                                           NaN
# GSM1012795                                                           NaN
# GSM1012796                                                           NaN
# GSM1012797                                                           NaN
# GSM1110889             protocol: molecular barcodes (MB) using a modi...
# GSM1110890             protocol: molecular barcodes (MB) using a modi...
# GSM1110891             protocol: molecular barcodes (MB) using a modi...
#
# !Sample_geo_accession                        !Sample_growth_protocol_ch1  \
# GSM1012777             Cells were cultured and stimulated with LPS as...
# GSM1012778             Cells were cultured and stimulated with LPS as...
# GSM1012779             Cells were cultured and stimulated with LPS as...
# GSM1012780             Cells were cultured and stimulated with LPS as...
# GSM1012781             Cells were cultured and stimulated with LPS as...
# GSM1012782             Cells were cultured and stimulated with LPS as...
# GSM1012783             Cells were cultured and stimulated with LPS as...
# GSM1012784             Cells were cultured and stimulated with LPS as...
# GSM1012785             Cells were cultured and stimulated with LPS as...
# GSM1012786             Cells were cultured and stimulated with LPS as...
# GSM1012787             Cells were cultured and stimulated with LPS as...
# GSM1012788             Cells were cultured and stimulated with LPS as...
# GSM1012789             Cells were cultured and stimulated with LPS as...
# GSM1012790             Cells were cultured and stimulated with LPS as...
# GSM1012791             Cells were cultured and stimulated with LPS as...
# GSM1012792             Cells were cultured and stimulated with LPS as...
# GSM1012793             Cells were cultured and stimulated with LPS as...
# GSM1012794             Cells were cultured and stimulated with LPS as...
# GSM1012795             Cells were cultured and stimulated with LPS as...
# GSM1012796             Cells were cultured and stimulated with LPS as...
# GSM1012797             Cells were cultured and stimulated with LPS as...
# GSM1110889             Cells were cultured and stimulated with LPS as...
# GSM1110890             Cells were cultured and stimulated with LPS as...
# GSM1110891             Cells were cultured and stimulated with LPS as...
#
# !Sample_geo_accession !Sample_molecule_ch1  \
# GSM1012777                       polyA RNA
# GSM1012778                       polyA RNA
# GSM1012779                       polyA RNA
# GSM1012780                       polyA RNA
# GSM1012781                       polyA RNA
# GSM1012782                       polyA RNA
# GSM1012783                       polyA RNA
# GSM1012784                       polyA RNA
# GSM1012785                       polyA RNA
# GSM1012786                       polyA RNA
# GSM1012787                       polyA RNA
# GSM1012788                       polyA RNA
# GSM1012789                       polyA RNA
# GSM1012790                       polyA RNA
# GSM1012791                       polyA RNA
# GSM1012792                       polyA RNA
# GSM1012793                       polyA RNA
# GSM1012794                       polyA RNA
# GSM1012795                       polyA RNA
# GSM1012796                       polyA RNA
# GSM1012797                       polyA RNA
# GSM1110889                       polyA RNA
# GSM1110890                       polyA RNA
# GSM1110891                       polyA RNA
#
# !Sample_geo_accession                       !Sample_extract_protocol_ch1  \
# GSM1012777                             cDNA synthesis and amplification:
# GSM1012778                             cDNA synthesis and amplification:
# GSM1012779                             cDNA synthesis and amplification:
# GSM1012780                             cDNA synthesis and amplification:
# GSM1012781                             cDNA synthesis and amplification:
# GSM1012782                             cDNA synthesis and amplification:
# GSM1012783                             cDNA synthesis and amplification:
# GSM1012784                             cDNA synthesis and amplification:
# GSM1012785                             cDNA synthesis and amplification:
# GSM1012786                             cDNA synthesis and amplification:
# GSM1012787                             cDNA synthesis and amplification:
# GSM1012788                             cDNA synthesis and amplification:
# GSM1012789                             cDNA synthesis and amplification:
# GSM1012790                             cDNA synthesis and amplification:
# GSM1012791                             cDNA synthesis and amplification:
# GSM1012792                             cDNA synthesis and amplification:
# GSM1012793                             cDNA synthesis and amplification:
# GSM1012794                             cDNA synthesis and amplification:
# GSM1012795                             cDNA synthesis and amplification:
# GSM1012796                             cDNA synthesis and amplification:
# GSM1012797                             cDNA synthesis and amplification:
# GSM1110889             cDNA from each sample was prepared using the S...
# GSM1110890             cDNA from each sample was prepared using the S...
# GSM1110891             cDNA from each sample was prepared using the S...
#
# !Sample_geo_accession                       !Sample_extract_protocol_ch1  \
# GSM1012777             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012778             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012779             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012780             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012781             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012782             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012783             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012784             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012785             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012786             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012787             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012788             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012789             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012790             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012791             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012792             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012793             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012794             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012795             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012796             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012797             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1110889             For the three molecular barcode (MB) libraries...
# GSM1110890             For the three molecular barcode (MB) libraries...
# GSM1110891             For the three molecular barcode (MB) libraries...
#
# !Sample_geo_accession                       !Sample_extract_protocol_ch1  \
# GSM1012777             We created Illumina sequencing libraries from ...
# GSM1012778             We created Illumina sequencing libraries from ...
# GSM1012779             We created Illumina sequencing libraries from ...
# GSM1012780             We created Illumina sequencing libraries from ...
# GSM1012781             We created Illumina sequencing libraries from ...
# GSM1012782             We created Illumina sequencing libraries from ...
# GSM1012783             We created Illumina sequencing libraries from ...
# GSM1012784             We created Illumina sequencing libraries from ...
# GSM1012785             We created Illumina sequencing libraries from ...
# GSM1012786             We created Illumina sequencing libraries from ...
# GSM1012787             We created Illumina sequencing libraries from ...
# GSM1012788             We created Illumina sequencing libraries from ...
# GSM1012789             We created Illumina sequencing libraries from ...
# GSM1012790             We created Illumina sequencing libraries from ...
# GSM1012791             We created Illumina sequencing libraries from ...
# GSM1012792             We created Illumina sequencing libraries from ...
# GSM1012793             We created Illumina sequencing libraries from ...
# GSM1012794             We created Illumina sequencing libraries from ...
# GSM1012795             We created Illumina sequencing libraries from ...
# GSM1012796             We created Illumina sequencing libraries from ...
# GSM1012797             We created Illumina sequencing libraries from ...
# GSM1110889                                                           NaN
# GSM1110890                                                           NaN
# GSM1110891                                                           NaN
#
# !Sample_geo_accession             !Sample_extract_protocol_ch1  \
# GSM1012777             cDNA shearing and library construction:
# GSM1012778             cDNA shearing and library construction:
# GSM1012779             cDNA shearing and library construction:
# GSM1012780             cDNA shearing and library construction:
# GSM1012781             cDNA shearing and library construction:
# GSM1012782             cDNA shearing and library construction:
# GSM1012783             cDNA shearing and library construction:
# GSM1012784             cDNA shearing and library construction:
# GSM1012785             cDNA shearing and library construction:
# GSM1012786             cDNA shearing and library construction:
# GSM1012787             cDNA shearing and library construction:
# GSM1012788             cDNA shearing and library construction:
# GSM1012789             cDNA shearing and library construction:
# GSM1012790             cDNA shearing and library construction:
# GSM1012791             cDNA shearing and library construction:
# GSM1012792             cDNA shearing and library construction:
# GSM1012793             cDNA shearing and library construction:
# GSM1012794             cDNA shearing and library construction:
# GSM1012795             cDNA shearing and library construction:
# GSM1012796             cDNA shearing and library construction:
# GSM1012797             cDNA shearing and library construction:
# GSM1110889                                                 NaN
# GSM1110890                                                 NaN
# GSM1110891                                                 NaN
#
# !Sample_geo_accession                       !Sample_extract_protocol_ch1  \
# GSM1012777             We added the purification buffer (Clontech) to...
# GSM1012778             We added the purification buffer (Clontech) to...
# GSM1012779             We added the purification buffer (Clontech) to...
# GSM1012780             We added the purification buffer (Clontech) to...
# GSM1012781             We added the purification buffer (Clontech) to...
# GSM1012782             We added the purification buffer (Clontech) to...
# GSM1012783             We added the purification buffer (Clontech) to...
# GSM1012784             We added the purification buffer (Clontech) to...
# GSM1012785             We added the purification buffer (Clontech) to...
# GSM1012786             We added the purification buffer (Clontech) to...
# GSM1012787             We added the purification buffer (Clontech) to...
# GSM1012788             We added the purification buffer (Clontech) to...
# GSM1012789             We added the purification buffer (Clontech) to...
# GSM1012790             We added the purification buffer (Clontech) to...
# GSM1012791             We added the purification buffer (Clontech) to...
# GSM1012792             We added the purification buffer (Clontech) to...
# GSM1012793             We added the purification buffer (Clontech) to...
# GSM1012794             We added the purification buffer (Clontech) to...
# GSM1012795             We added the purification buffer (Clontech) to...
# GSM1012796             We added the purification buffer (Clontech) to...
# GSM1012797             We added the purification buffer (Clontech) to...
# GSM1110889                                                           NaN
# GSM1110890                                                           NaN
# GSM1110891                                                           NaN
#
# !Sample_geo_accession                       !Sample_extract_protocol_ch1  \
# GSM1012777             We prepared indexed paired-end libraries for I...
# GSM1012778             We prepared indexed paired-end libraries for I...
# GSM1012779             We prepared indexed paired-end libraries for I...
# GSM1012780             We prepared indexed paired-end libraries for I...
# GSM1012781             We prepared indexed paired-end libraries for I...
# GSM1012782             We prepared indexed paired-end libraries for I...
# GSM1012783             We prepared indexed paired-end libraries for I...
# GSM1012784             We prepared indexed paired-end libraries for I...
# GSM1012785             We prepared indexed paired-end libraries for I...
# GSM1012786             We prepared indexed paired-end libraries for I...
# GSM1012787             We prepared indexed paired-end libraries for I...
# GSM1012788             We prepared indexed paired-end libraries for I...
# GSM1012789             We prepared indexed paired-end libraries for I...
# GSM1012790             We prepared indexed paired-end libraries for I...
# GSM1012791             We prepared indexed paired-end libraries for I...
# GSM1012792             We prepared indexed paired-end libraries for I...
# GSM1012793             We prepared indexed paired-end libraries for I...
# GSM1012794             We prepared indexed paired-end libraries for I...
# GSM1012795             We prepared indexed paired-end libraries for I...
# GSM1012796             We prepared indexed paired-end libraries for I...
# GSM1012797             We prepared indexed paired-end libraries for I...
# GSM1110889                                                           NaN
# GSM1110890                                                           NaN
# GSM1110891                                                           NaN
#
# !Sample_geo_accession !Sample_taxid_ch1 !Sample_description  \
# GSM1012777                        10090                  S1
# GSM1012778                        10090                  S2
# GSM1012779                        10090                  S3
# GSM1012780                        10090                  S4
# GSM1012781                        10090                  S5
# GSM1012782                        10090                  S6
# GSM1012783                        10090                  S7
# GSM1012784                        10090                  S8
# GSM1012785                        10090                  S9
# GSM1012786                        10090                 S10
# GSM1012787                        10090                 S11
# GSM1012788                        10090                 S12
# GSM1012789                        10090                 S13
# GSM1012790                        10090                 S14
# GSM1012791                        10090                 S15
# GSM1012792                        10090                 S16
# GSM1012793                        10090                 S17
# GSM1012794                        10090                 S18
# GSM1012795                        10090             S19_10k
# GSM1012796                        10090             S20_10k
# GSM1012797                        10090             S21_10k
# GSM1110889                        10090                 MB1
# GSM1110890                        10090                 MB2
# GSM1110891                        10090                 MB3
#
# !Sample_geo_accession                            !Sample_data_processing  \
# GSM1012777             We created a Bowtie index based on the UCSC kn...
# GSM1012778             We created a Bowtie index based on the UCSC kn...
# GSM1012779             We created a Bowtie index based on the UCSC kn...
# GSM1012780             We created a Bowtie index based on the UCSC kn...
# GSM1012781             We created a Bowtie index based on the UCSC kn...
# GSM1012782             We created a Bowtie index based on the UCSC kn...
# GSM1012783             We created a Bowtie index based on the UCSC kn...
# GSM1012784             We created a Bowtie index based on the UCSC kn...
# GSM1012785             We created a Bowtie index based on the UCSC kn...
# GSM1012786             We created a Bowtie index based on the UCSC kn...
# GSM1012787             We created a Bowtie index based on the UCSC kn...
# GSM1012788             We created a Bowtie index based on the UCSC kn...
# GSM1012789             We created a Bowtie index based on the UCSC kn...
# GSM1012790             We created a Bowtie index based on the UCSC kn...
# GSM1012791             We created a Bowtie index based on the UCSC kn...
# GSM1012792             We created a Bowtie index based on the UCSC kn...
# GSM1012793             We created a Bowtie index based on the UCSC kn...
# GSM1012794             We created a Bowtie index based on the UCSC kn...
# GSM1012795             We created a Bowtie index based on the UCSC kn...
# GSM1012796             We created a Bowtie index based on the UCSC kn...
# GSM1012797             We created a Bowtie index based on the UCSC kn...
# GSM1110889             We created a Bowtie index based on the UCSC kn...
# GSM1110890             We created a Bowtie index based on the UCSC kn...
# GSM1110891             We created a Bowtie index based on the UCSC kn...
#
# !Sample_geo_accession                            !Sample_data_processing  \
# GSM1012777             Next, we ran RSEM v1.11 with default parameter...
# GSM1012778             Next, we ran RSEM v1.11 with default parameter...
# GSM1012779             Next, we ran RSEM v1.11 with default parameter...
# GSM1012780             Next, we ran RSEM v1.11 with default parameter...
# GSM1012781             Next, we ran RSEM v1.11 with default parameter...
# GSM1012782             Next, we ran RSEM v1.11 with default parameter...
# GSM1012783             Next, we ran RSEM v1.11 with default parameter...
# GSM1012784             Next, we ran RSEM v1.11 with default parameter...
# GSM1012785             Next, we ran RSEM v1.11 with default parameter...
# GSM1012786             Next, we ran RSEM v1.11 with default parameter...
# GSM1012787             Next, we ran RSEM v1.11 with default parameter...
# GSM1012788             Next, we ran RSEM v1.11 with default parameter...
# GSM1012789             Next, we ran RSEM v1.11 with default parameter...
# GSM1012790             Next, we ran RSEM v1.11 with default parameter...
# GSM1012791             Next, we ran RSEM v1.11 with default parameter...
# GSM1012792             Next, we ran RSEM v1.11 with default parameter...
# GSM1012793             Next, we ran RSEM v1.11 with default parameter...
# GSM1012794             Next, we ran RSEM v1.11 with default parameter...
# GSM1012795             Next, we ran RSEM v1.11 with default parameter...
# GSM1012796             Next, we ran RSEM v1.11 with default parameter...
# GSM1012797             Next, we ran RSEM v1.11 with default parameter...
# GSM1110889             Next, we ran RSEM v1.11 with default parameter...
# GSM1110890             Next, we ran RSEM v1.11 with default parameter...
# GSM1110891             Next, we ran RSEM v1.11 with default parameter...
#
# !Sample_geo_accession !Sample_data_processing  \
# GSM1012777                  Genome_build: mm9
# GSM1012778                  Genome_build: mm9
# GSM1012779                  Genome_build: mm9
# GSM1012780                  Genome_build: mm9
# GSM1012781                  Genome_build: mm9
# GSM1012782                  Genome_build: mm9
# GSM1012783                  Genome_build: mm9
# GSM1012784                  Genome_build: mm9
# GSM1012785                  Genome_build: mm9
# GSM1012786                  Genome_build: mm9
# GSM1012787                  Genome_build: mm9
# GSM1012788                  Genome_build: mm9
# GSM1012789                  Genome_build: mm9
# GSM1012790                  Genome_build: mm9
# GSM1012791                  Genome_build: mm9
# GSM1012792                  Genome_build: mm9
# GSM1012793                  Genome_build: mm9
# GSM1012794                  Genome_build: mm9
# GSM1012795                  Genome_build: mm9
# GSM1012796                  Genome_build: mm9
# GSM1012797                  Genome_build: mm9
# GSM1110889                  Genome_build: mm9
# GSM1110890                  Genome_build: mm9
# GSM1110891                  Genome_build: mm9
#
# !Sample_geo_accession                            !Sample_data_processing  \
# GSM1012777             Supplementary_files_format_and_content: File a...
# GSM1012778             Supplementary_files_format_and_content: File a...
# GSM1012779             Supplementary_files_format_and_content: File a...
# GSM1012780             Supplementary_files_format_and_content: File a...
# GSM1012781             Supplementary_files_format_and_content: File a...
# GSM1012782             Supplementary_files_format_and_content: File a...
# GSM1012783             Supplementary_files_format_and_content: File a...
# GSM1012784             Supplementary_files_format_and_content: File a...
# GSM1012785             Supplementary_files_format_and_content: File a...
# GSM1012786             Supplementary_files_format_and_content: File a...
# GSM1012787             Supplementary_files_format_and_content: File a...
# GSM1012788             Supplementary_files_format_and_content: File a...
# GSM1012789             Supplementary_files_format_and_content: File a...
# GSM1012790             Supplementary_files_format_and_content: File a...
# GSM1012791             Supplementary_files_format_and_content: File a...
# GSM1012792             Supplementary_files_format_and_content: File a...
# GSM1012793             Supplementary_files_format_and_content: File a...
# GSM1012794             Supplementary_files_format_and_content: File a...
# GSM1012795             Supplementary_files_format_and_content: File a...
# GSM1012796             Supplementary_files_format_and_content: File a...
# GSM1012797             Supplementary_files_format_and_content: File a...
# GSM1110889             Supplementary_files_format_and_content: File a...
# GSM1110890             Supplementary_files_format_and_content: File a...
# GSM1110891             Supplementary_files_format_and_content: File a...
#
# !Sample_geo_accession !Sample_platform_id !Sample_contact_name  \
# GSM1012777                       GPL13112        Rahul,,Satija
# GSM1012778                       GPL13112        Rahul,,Satija
# GSM1012779                       GPL13112        Rahul,,Satija
# GSM1012780                       GPL13112        Rahul,,Satija
# GSM1012781                       GPL13112        Rahul,,Satija
# GSM1012782                       GPL13112        Rahul,,Satija
# GSM1012783                       GPL13112        Rahul,,Satija
# GSM1012784                       GPL13112        Rahul,,Satija
# GSM1012785                       GPL13112        Rahul,,Satija
# GSM1012786                       GPL13112        Rahul,,Satija
# GSM1012787                       GPL13112        Rahul,,Satija
# GSM1012788                       GPL13112        Rahul,,Satija
# GSM1012789                       GPL13112        Rahul,,Satija
# GSM1012790                       GPL13112        Rahul,,Satija
# GSM1012791                       GPL13112        Rahul,,Satija
# GSM1012792                       GPL13112        Rahul,,Satija
# GSM1012793                       GPL13112        Rahul,,Satija
# GSM1012794                       GPL13112        Rahul,,Satija
# GSM1012795                       GPL13112        Rahul,,Satija
# GSM1012796                       GPL13112        Rahul,,Satija
# GSM1012797                       GPL13112        Rahul,,Satija
# GSM1110889                       GPL13112        Rahul,,Satija
# GSM1110890                       GPL13112        Rahul,,Satija
# GSM1110891                       GPL13112        Rahul,,Satija
#
# !Sample_geo_accession !Sample_contact_email !Sample_contact_phone  \
# GSM1012777             rsatija@nygenome.org            6177022468
# GSM1012778             rsatija@nygenome.org            6177022468
# GSM1012779             rsatija@nygenome.org            6177022468
# GSM1012780             rsatija@nygenome.org            6177022468
# GSM1012781             rsatija@nygenome.org            6177022468
# GSM1012782             rsatija@nygenome.org            6177022468
# GSM1012783             rsatija@nygenome.org            6177022468
# GSM1012784             rsatija@nygenome.org            6177022468
# GSM1012785             rsatija@nygenome.org            6177022468
# GSM1012786             rsatija@nygenome.org            6177022468
# GSM1012787             rsatija@nygenome.org            6177022468
# GSM1012788             rsatija@nygenome.org            6177022468
# GSM1012789             rsatija@nygenome.org            6177022468
# GSM1012790             rsatija@nygenome.org            6177022468
# GSM1012791             rsatija@nygenome.org            6177022468
# GSM1012792             rsatija@nygenome.org            6177022468
# GSM1012793             rsatija@nygenome.org            6177022468
# GSM1012794             rsatija@nygenome.org            6177022468
# GSM1012795             rsatija@nygenome.org            6177022468
# GSM1012796             rsatija@nygenome.org            6177022468
# GSM1012797             rsatija@nygenome.org            6177022468
# GSM1110889             rsatija@nygenome.org            6177022468
# GSM1110890             rsatija@nygenome.org            6177022468
# GSM1110891             rsatija@nygenome.org            6177022468
#
# !Sample_geo_accession !Sample_contact_laboratory !Sample_contact_institute  \
# GSM1012777                            Satija Lab    New York Genome Center
# GSM1012778                            Satija Lab    New York Genome Center
# GSM1012779                            Satija Lab    New York Genome Center
# GSM1012780                            Satija Lab    New York Genome Center
# GSM1012781                            Satija Lab    New York Genome Center
# GSM1012782                            Satija Lab    New York Genome Center
# GSM1012783                            Satija Lab    New York Genome Center
# GSM1012784                            Satija Lab    New York Genome Center
# GSM1012785                            Satija Lab    New York Genome Center
# GSM1012786                            Satija Lab    New York Genome Center
# GSM1012787                            Satija Lab    New York Genome Center
# GSM1012788                            Satija Lab    New York Genome Center
# GSM1012789                            Satija Lab    New York Genome Center
# GSM1012790                            Satija Lab    New York Genome Center
# GSM1012791                            Satija Lab    New York Genome Center
# GSM1012792                            Satija Lab    New York Genome Center
# GSM1012793                            Satija Lab    New York Genome Center
# GSM1012794                            Satija Lab    New York Genome Center
# GSM1012795                            Satija Lab    New York Genome Center
# GSM1012796                            Satija Lab    New York Genome Center
# GSM1012797                            Satija Lab    New York Genome Center
# GSM1110889                            Satija Lab    New York Genome Center
# GSM1110890                            Satija Lab    New York Genome Center
# GSM1110891                            Satija Lab    New York Genome Center
#
# !Sample_geo_accession     !Sample_contact_address !Sample_contact_city  \
# GSM1012777             101 Avenue of the Americas        New York City
# GSM1012778             101 Avenue of the Americas        New York City
# GSM1012779             101 Avenue of the Americas        New York City
# GSM1012780             101 Avenue of the Americas        New York City
# GSM1012781             101 Avenue of the Americas        New York City
# GSM1012782             101 Avenue of the Americas        New York City
# GSM1012783             101 Avenue of the Americas        New York City
# GSM1012784             101 Avenue of the Americas        New York City
# GSM1012785             101 Avenue of the Americas        New York City
# GSM1012786             101 Avenue of the Americas        New York City
# GSM1012787             101 Avenue of the Americas        New York City
# GSM1012788             101 Avenue of the Americas        New York City
# GSM1012789             101 Avenue of the Americas        New York City
# GSM1012790             101 Avenue of the Americas        New York City
# GSM1012791             101 Avenue of the Americas        New York City
# GSM1012792             101 Avenue of the Americas        New York City
# GSM1012793             101 Avenue of the Americas        New York City
# GSM1012794             101 Avenue of the Americas        New York City
# GSM1012795             101 Avenue of the Americas        New York City
# GSM1012796             101 Avenue of the Americas        New York City
# GSM1012797             101 Avenue of the Americas        New York City
# GSM1110889             101 Avenue of the Americas        New York City
# GSM1110890             101 Avenue of the Americas        New York City
# GSM1110891             101 Avenue of the Americas        New York City
#
# !Sample_geo_accession !Sample_contact_state !Sample_contact_zip/postal_code  \
# GSM1012777                               NY                           10013
# GSM1012778                               NY                           10013
# GSM1012779                               NY                           10013
# GSM1012780                               NY                           10013
# GSM1012781                               NY                           10013
# GSM1012782                               NY                           10013
# GSM1012783                               NY                           10013
# GSM1012784                               NY                           10013
# GSM1012785                               NY                           10013
# GSM1012786                               NY                           10013
# GSM1012787                               NY                           10013
# GSM1012788                               NY                           10013
# GSM1012789                               NY                           10013
# GSM1012790                               NY                           10013
# GSM1012791                               NY                           10013
# GSM1012792                               NY                           10013
# GSM1012793                               NY                           10013
# GSM1012794                               NY                           10013
# GSM1012795                               NY                           10013
# GSM1012796                               NY                           10013
# GSM1012797                               NY                           10013
# GSM1110889                               NY                           10013
# GSM1110890                               NY                           10013
# GSM1110891                               NY                           10013
#
# !Sample_geo_accession !Sample_contact_country !Sample_data_row_count  \
# GSM1012777                                USA                      0
# GSM1012778                                USA                      0
# GSM1012779                                USA                      0
# GSM1012780                                USA                      0
# GSM1012781                                USA                      0
# GSM1012782                                USA                      0
# GSM1012783                                USA                      0
# GSM1012784                                USA                      0
# GSM1012785                                USA                      0
# GSM1012786                                USA                      0
# GSM1012787                                USA                      0
# GSM1012788                                USA                      0
# GSM1012789                                USA                      0
# GSM1012790                                USA                      0
# GSM1012791                                USA                      0
# GSM1012792                                USA                      0
# GSM1012793                                USA                      0
# GSM1012794                                USA                      0
# GSM1012795                                USA                      0
# GSM1012796                                USA                      0
# GSM1012797                                USA                      0
# GSM1110889                                USA                      0
# GSM1110890                                USA                      0
# GSM1110891                                USA                      0
#
# !Sample_geo_accession !Sample_instrument_model !Sample_library_selection  \
# GSM1012777                 Illumina HiSeq 2000                      cDNA
# GSM1012778                 Illumina HiSeq 2000                      cDNA
# GSM1012779                 Illumina HiSeq 2000                      cDNA
# GSM1012780                 Illumina HiSeq 2000                      cDNA
# GSM1012781                 Illumina HiSeq 2000                      cDNA
# GSM1012782                 Illumina HiSeq 2000                      cDNA
# GSM1012783                 Illumina HiSeq 2000                      cDNA
# GSM1012784                 Illumina HiSeq 2000                      cDNA
# GSM1012785                 Illumina HiSeq 2000                      cDNA
# GSM1012786                 Illumina HiSeq 2000                      cDNA
# GSM1012787                 Illumina HiSeq 2000                      cDNA
# GSM1012788                 Illumina HiSeq 2000                      cDNA
# GSM1012789                 Illumina HiSeq 2000                      cDNA
# GSM1012790                 Illumina HiSeq 2000                      cDNA
# GSM1012791                 Illumina HiSeq 2000                      cDNA
# GSM1012792                 Illumina HiSeq 2000                      cDNA
# GSM1012793                 Illumina HiSeq 2000                      cDNA
# GSM1012794                 Illumina HiSeq 2000                      cDNA
# GSM1012795                 Illumina HiSeq 2000                      cDNA
# GSM1012796                 Illumina HiSeq 2000                      cDNA
# GSM1012797                 Illumina HiSeq 2000                      cDNA
# GSM1110889                 Illumina HiSeq 2000                      cDNA
# GSM1110890                 Illumina HiSeq 2000                      cDNA
# GSM1110891                 Illumina HiSeq 2000                      cDNA
#
# !Sample_geo_accession !Sample_library_source !Sample_library_strategy  \
# GSM1012777                    transcriptomic                  RNA-Seq
# GSM1012778                    transcriptomic                  RNA-Seq
# GSM1012779                    transcriptomic                  RNA-Seq
# GSM1012780                    transcriptomic                  RNA-Seq
# GSM1012781                    transcriptomic                  RNA-Seq
# GSM1012782                    transcriptomic                  RNA-Seq
# GSM1012783                    transcriptomic                  RNA-Seq
# GSM1012784                    transcriptomic                  RNA-Seq
# GSM1012785                    transcriptomic                  RNA-Seq
# GSM1012786                    transcriptomic                  RNA-Seq
# GSM1012787                    transcriptomic                  RNA-Seq
# GSM1012788                    transcriptomic                  RNA-Seq
# GSM1012789                    transcriptomic                  RNA-Seq
# GSM1012790                    transcriptomic                  RNA-Seq
# GSM1012791                    transcriptomic                  RNA-Seq
# GSM1012792                    transcriptomic                  RNA-Seq
# GSM1012793                    transcriptomic                  RNA-Seq
# GSM1012794                    transcriptomic                  RNA-Seq
# GSM1012795                    transcriptomic                  RNA-Seq
# GSM1012796                    transcriptomic                  RNA-Seq
# GSM1012797                    transcriptomic                  RNA-Seq
# GSM1110889                    transcriptomic                  RNA-Seq
# GSM1110890                    transcriptomic                  RNA-Seq
# GSM1110891                    transcriptomic                  RNA-Seq
#
# !Sample_geo_accession                                   !Sample_relation  \
# GSM1012777             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012778             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012779             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012780             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012781             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012782             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012783             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012784             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012785             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012786             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012787             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012788             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012789             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012790             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012791             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012792             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012793             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012794             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012795             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012796             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012797             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1110889             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1110890             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1110891             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
#
# !Sample_geo_accession                                   !Sample_relation  \
# GSM1012777             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012778             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012779             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012780             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012781             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012782             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012783             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012784             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012785             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012786             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012787             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012788             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012789             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012790             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012791             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012792             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012793             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012794             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012795             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012796             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012797             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1110889             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1110890             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1110891             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
#
# !Sample_geo_accession !Sample_supplementary_file_1 !series_matrix_table_begin  \
# GSM1012777                                    NONE                        NaN
# GSM1012778                                    NONE                        NaN
# GSM1012779                                    NONE                        NaN
# GSM1012780                                    NONE                        NaN
# GSM1012781                                    NONE                        NaN
# GSM1012782                                    NONE                        NaN
# GSM1012783                                    NONE                        NaN
# GSM1012784                                    NONE                        NaN
# GSM1012785                                    NONE                        NaN
# GSM1012786                                    NONE                        NaN
# GSM1012787                                    NONE                        NaN
# GSM1012788                                    NONE                        NaN
# GSM1012789                                    NONE                        NaN
# GSM1012790                                    NONE                        NaN
# GSM1012791                                    NONE                        NaN
# GSM1012792                                    NONE                        NaN
# GSM1012793                                    NONE                        NaN
# GSM1012794                                    NONE                        NaN
# GSM1012795                                    NONE                        NaN
# GSM1012796                                    NONE                        NaN
# GSM1012797                                    NONE                        NaN
# GSM1110889                                    NONE                        NaN
# GSM1110890                                    NONE                        NaN
# GSM1110891                                    NONE                        NaN
#
# !Sample_geo_accession      ID_REF !series_matrix_table_end
# GSM1012777             GSM1012777                      NaN
# GSM1012778             GSM1012778                      NaN
# GSM1012779             GSM1012779                      NaN
# GSM1012780             GSM1012780                      NaN
# GSM1012781             GSM1012781                      NaN
# GSM1012782             GSM1012782                      NaN
# GSM1012783             GSM1012783                      NaN
# GSM1012784             GSM1012784                      NaN
# GSM1012785             GSM1012785                      NaN
# GSM1012786             GSM1012786                      NaN
# GSM1012787             GSM1012787                      NaN
# GSM1012788             GSM1012788                      NaN
# GSM1012789             GSM1012789                      NaN
# GSM1012790             GSM1012790                      NaN
# GSM1012791             GSM1012791                      NaN
# GSM1012792             GSM1012792                      NaN
# GSM1012793             GSM1012793                      NaN
# GSM1012794             GSM1012794                      NaN
# GSM1012795             GSM1012795                      NaN
# GSM1012796             GSM1012796                      NaN
# GSM1012797             GSM1012797                      NaN
# GSM1110889             GSM1110889                      NaN
# GSM1110890             GSM1110890                      NaN
# GSM1110891             GSM1110891                      NaN

# %% [markdown]
# Now we'll do some mild data cleaning. Notice that the columns have the exclamation point at the beginning, so let's get rid of that. In computer science, you keep letters between quotes, and you call those "strings." Let's talk about the string function `.strip()`. This removes any characters that are on the outer edges of the string. For example, let's take the string "Whoooo!!!!!!!"

# %% [markdown]
# We can access the column names with `dataframe.columns`, like below:

# %%
shalek2013_metadata.columns
# Out:
# Index(['!Sample_status', '!Sample_submission_date', '!Sample_last_update_date',
#        '!Sample_type', '!Sample_channel_count', '!Sample_source_name_ch1',
#        '!Sample_organism_ch1', '!Sample_characteristics_ch1',
#        '!Sample_characteristics_ch1', '!Sample_characteristics_ch1',
#        '!Sample_characteristics_ch1', '!Sample_characteristics_ch1',
#        '!Sample_growth_protocol_ch1', '!Sample_molecule_ch1',
#        '!Sample_extract_protocol_ch1', '!Sample_extract_protocol_ch1',
#        '!Sample_extract_protocol_ch1', '!Sample_extract_protocol_ch1',
#        '!Sample_extract_protocol_ch1', '!Sample_extract_protocol_ch1',
#        '!Sample_taxid_ch1', '!Sample_description', '!Sample_data_processing',
#        '!Sample_data_processing', '!Sample_data_processing',
#        '!Sample_data_processing', '!Sample_platform_id',
#        '!Sample_contact_name', '!Sample_contact_email',
#        '!Sample_contact_phone', '!Sample_contact_laboratory',
#        '!Sample_contact_institute', '!Sample_contact_address',
#        '!Sample_contact_city', '!Sample_contact_state',
#        '!Sample_contact_zip/postal_code', '!Sample_contact_country',
#        '!Sample_data_row_count', '!Sample_instrument_model',
#        '!Sample_library_selection', '!Sample_library_source',
#        '!Sample_library_strategy', '!Sample_relation', '!Sample_relation',
#        '!Sample_supplementary_file_1', '!series_matrix_table_begin', 'ID_REF',
#        '!series_matrix_table_end'],
#       dtype='object', name='!Sample_geo_accession')

# %% [markdown]
# We can map the stripping function to every item of the columns. In Python, the square brackets (`[` and `]`) show that we're making a list. What we're doing below is called a "list comprehension."

# %%
[x.strip('!') for x in shalek2013_metadata.columns]
# Out:
# ['Sample_status',
#  'Sample_submission_date',
#  'Sample_last_update_date',
#  'Sample_type',
#  'Sample_channel_count',
#  'Sample_source_name_ch1',
#  'Sample_organism_ch1',
#  'Sample_characteristics_ch1',
#  'Sample_characteristics_ch1',
#  'Sample_characteristics_ch1',
#  'Sample_characteristics_ch1',
#  'Sample_characteristics_ch1',
#  'Sample_growth_protocol_ch1',
#  'Sample_molecule_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_extract_protocol_ch1',
#  'Sample_taxid_ch1',
#  'Sample_description',
#  'Sample_data_processing',
#  'Sample_data_processing',
#  'Sample_data_processing',
#  'Sample_data_processing',
#  'Sample_platform_id',
#  'Sample_contact_name',
#  'Sample_contact_email',
#  'Sample_contact_phone',
#  'Sample_contact_laboratory',
#  'Sample_contact_institute',
#  'Sample_contact_address',
#  'Sample_contact_city',
#  'Sample_contact_state',
#  'Sample_contact_zip/postal_code',
#  'Sample_contact_country',
#  'Sample_data_row_count',
#  'Sample_instrument_model',
#  'Sample_library_selection',
#  'Sample_library_source',
#  'Sample_library_strategy',
#  'Sample_relation',
#  'Sample_relation',
#  'Sample_supplementary_file_1',
#  'series_matrix_table_begin',
#  'ID_REF',
#  'series_matrix_table_end']

# %% [markdown]
# In `pandas`, we can do the same thing by `map`-ping a `lambda`, which is a small, anonymous function that does one thing. It's called "anonymous" because it doesn't have a name. `map` runs the function on every element of the columns.

# %%
shalek2013_metadata.columns.map(lambda x: x.strip('!'))
# Out:
# Index(['Sample_status', 'Sample_submission_date', 'Sample_last_update_date',
#        'Sample_type', 'Sample_channel_count', 'Sample_source_name_ch1',
#        'Sample_organism_ch1', 'Sample_characteristics_ch1',
#        'Sample_characteristics_ch1', 'Sample_characteristics_ch1',
#        'Sample_characteristics_ch1', 'Sample_characteristics_ch1',
#        'Sample_growth_protocol_ch1', 'Sample_molecule_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_taxid_ch1', 'Sample_description', 'Sample_data_processing',
#        'Sample_data_processing', 'Sample_data_processing',
#        'Sample_data_processing', 'Sample_platform_id', 'Sample_contact_name',
#        'Sample_contact_email', 'Sample_contact_phone',
#        'Sample_contact_laboratory', 'Sample_contact_institute',
#        'Sample_contact_address', 'Sample_contact_city', 'Sample_contact_state',
#        'Sample_contact_zip/postal_code', 'Sample_contact_country',
#        'Sample_data_row_count', 'Sample_instrument_model',
#        'Sample_library_selection', 'Sample_library_source',
#        'Sample_library_strategy', 'Sample_relation', 'Sample_relation',
#        'Sample_supplementary_file_1', 'series_matrix_table_begin', 'ID_REF',
#        'series_matrix_table_end'],
#       dtype='object', name='!Sample_geo_accession')

# %% [markdown]
# The above `lambda` is the same as if we had written a *named* function called `remove_exclamation`, as below.

# %%
def remove_exclamation(x):
    return x.strip('!')

shalek2013_metadata.columns.map(remove_exclamation)
# Out:
# Index(['Sample_status', 'Sample_submission_date', 'Sample_last_update_date',
#        'Sample_type', 'Sample_channel_count', 'Sample_source_name_ch1',
#        'Sample_organism_ch1', 'Sample_characteristics_ch1',
#        'Sample_characteristics_ch1', 'Sample_characteristics_ch1',
#        'Sample_characteristics_ch1', 'Sample_characteristics_ch1',
#        'Sample_growth_protocol_ch1', 'Sample_molecule_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_extract_protocol_ch1', 'Sample_extract_protocol_ch1',
#        'Sample_taxid_ch1', 'Sample_description', 'Sample_data_processing',
#        'Sample_data_processing', 'Sample_data_processing',
#        'Sample_data_processing', 'Sample_platform_id', 'Sample_contact_name',
#        'Sample_contact_email', 'Sample_contact_phone',
#        'Sample_contact_laboratory', 'Sample_contact_institute',
#        'Sample_contact_address', 'Sample_contact_city', 'Sample_contact_state',
#        'Sample_contact_zip/postal_code', 'Sample_contact_country',
#        'Sample_data_row_count', 'Sample_instrument_model',
#        'Sample_library_selection', 'Sample_library_source',
#        'Sample_library_strategy', 'Sample_relation', 'Sample_relation',
#        'Sample_supplementary_file_1', 'series_matrix_table_begin', 'ID_REF',
#        'series_matrix_table_end'],
#       dtype='object', name='!Sample_geo_accession')

# %% [markdown]
# Now we can assign the new column names to our matrix:

# %%
shalek2013_metadata.columns = shalek2013_metadata.columns.map(lambda x: x.strip('!'))
shalek2013_metadata.head()
# Out:
# !Sample_geo_accession          Sample_status Sample_submission_date  \
# GSM1012777             Public on May 19 2013            Oct 01 2012
# GSM1012778             Public on May 19 2013            Oct 01 2012
# GSM1012779             Public on May 19 2013            Oct 01 2012
# GSM1012780             Public on May 19 2013            Oct 01 2012
# GSM1012781             Public on May 19 2013            Oct 01 2012
#
# !Sample_geo_accession Sample_last_update_date Sample_type  \
# GSM1012777                        May 19 2013         SRA
# GSM1012778                        May 19 2013         SRA
# GSM1012779                        May 19 2013         SRA
# GSM1012780                        May 19 2013         SRA
# GSM1012781                        May 19 2013         SRA
#
# !Sample_geo_accession Sample_channel_count Sample_source_name_ch1  \
# GSM1012777                               1     BMDC (4h LPS stim)
# GSM1012778                               1     BMDC (4h LPS stim)
# GSM1012779                               1     BMDC (4h LPS stim)
# GSM1012780                               1     BMDC (4h LPS stim)
# GSM1012781                               1     BMDC (4h LPS stim)
#
# !Sample_geo_accession Sample_organism_ch1 Sample_characteristics_ch1  \
# GSM1012777                   Mus musculus            strain: C57BL/6
# GSM1012778                   Mus musculus            strain: C57BL/6
# GSM1012779                   Mus musculus            strain: C57BL/6
# GSM1012780                   Mus musculus            strain: C57BL/6
# GSM1012781                   Mus musculus            strain: C57BL/6
#
# !Sample_geo_accession                         Sample_characteristics_ch1  \
# GSM1012777             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012778             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012779             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012780             cell type: Bone Marrow-derived Dendritic Cell ...
# GSM1012781             cell type: Bone Marrow-derived Dendritic Cell ...
#
# !Sample_geo_accession  Sample_characteristics_ch1 Sample_characteristics_ch1  \
# GSM1012777             treatment: LPS-stimulation         cell count: 1 cell
# GSM1012778             treatment: LPS-stimulation         cell count: 1 cell
# GSM1012779             treatment: LPS-stimulation         cell count: 1 cell
# GSM1012780             treatment: LPS-stimulation         cell count: 1 cell
# GSM1012781             treatment: LPS-stimulation         cell count: 1 cell
#
# !Sample_geo_accession Sample_characteristics_ch1  \
# GSM1012777                                   NaN
# GSM1012778                                   NaN
# GSM1012779                                   NaN
# GSM1012780                                   NaN
# GSM1012781                                   NaN
#
# !Sample_geo_accession                         Sample_growth_protocol_ch1  \
# GSM1012777             Cells were cultured and stimulated with LPS as...
# GSM1012778             Cells were cultured and stimulated with LPS as...
# GSM1012779             Cells were cultured and stimulated with LPS as...
# GSM1012780             Cells were cultured and stimulated with LPS as...
# GSM1012781             Cells were cultured and stimulated with LPS as...
#
# !Sample_geo_accession Sample_molecule_ch1        Sample_extract_protocol_ch1  \
# GSM1012777                      polyA RNA  cDNA synthesis and amplification:
# GSM1012778                      polyA RNA  cDNA synthesis and amplification:
# GSM1012779                      polyA RNA  cDNA synthesis and amplification:
# GSM1012780                      polyA RNA  cDNA synthesis and amplification:
# GSM1012781                      polyA RNA  cDNA synthesis and amplification:
#
# !Sample_geo_accession                        Sample_extract_protocol_ch1  \
# GSM1012777             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012778             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012779             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012780             We used the SMARTer Ultra Low RNA Kit (Clontec...
# GSM1012781             We used the SMARTer Ultra Low RNA Kit (Clontec...
#
# !Sample_geo_accession                        Sample_extract_protocol_ch1  \
# GSM1012777             We created Illumina sequencing libraries from ...
# GSM1012778             We created Illumina sequencing libraries from ...
# GSM1012779             We created Illumina sequencing libraries from ...
# GSM1012780             We created Illumina sequencing libraries from ...
# GSM1012781             We created Illumina sequencing libraries from ...
#
# !Sample_geo_accession              Sample_extract_protocol_ch1  \
# GSM1012777             cDNA shearing and library construction:
# GSM1012778             cDNA shearing and library construction:
# GSM1012779             cDNA shearing and library construction:
# GSM1012780             cDNA shearing and library construction:
# GSM1012781             cDNA shearing and library construction:
#
# !Sample_geo_accession                        Sample_extract_protocol_ch1  \
# GSM1012777             We added the purification buffer (Clontech) to...
# GSM1012778             We added the purification buffer (Clontech) to...
# GSM1012779             We added the purification buffer (Clontech) to...
# GSM1012780             We added the purification buffer (Clontech) to...
# GSM1012781             We added the purification buffer (Clontech) to...
#
# !Sample_geo_accession                        Sample_extract_protocol_ch1  \
# GSM1012777             We prepared indexed paired-end libraries for I...
# GSM1012778             We prepared indexed paired-end libraries for I...
# GSM1012779             We prepared indexed paired-end libraries for I...
# GSM1012780             We prepared indexed paired-end libraries for I...
# GSM1012781             We prepared indexed paired-end libraries for I...
#
# !Sample_geo_accession Sample_taxid_ch1 Sample_description  \
# GSM1012777                       10090                 S1
# GSM1012778                       10090                 S2
# GSM1012779                       10090                 S3
# GSM1012780                       10090                 S4
# GSM1012781                       10090                 S5
#
# !Sample_geo_accession                             Sample_data_processing  \
# GSM1012777             We created a Bowtie index based on the UCSC kn...
# GSM1012778             We created a Bowtie index based on the UCSC kn...
# GSM1012779             We created a Bowtie index based on the UCSC kn...
# GSM1012780             We created a Bowtie index based on the UCSC kn...
# GSM1012781             We created a Bowtie index based on the UCSC kn...
#
# !Sample_geo_accession                             Sample_data_processing  \
# GSM1012777             Next, we ran RSEM v1.11 with default parameter...
# GSM1012778             Next, we ran RSEM v1.11 with default parameter...
# GSM1012779             Next, we ran RSEM v1.11 with default parameter...
# GSM1012780             Next, we ran RSEM v1.11 with default parameter...
# GSM1012781             Next, we ran RSEM v1.11 with default parameter...
#
# !Sample_geo_accession Sample_data_processing  \
# GSM1012777                 Genome_build: mm9
# GSM1012778                 Genome_build: mm9
# GSM1012779                 Genome_build: mm9
# GSM1012780                 Genome_build: mm9
# GSM1012781                 Genome_build: mm9
#
# !Sample_geo_accession                             Sample_data_processing  \
# GSM1012777             Supplementary_files_format_and_content: File a...
# GSM1012778             Supplementary_files_format_and_content: File a...
# GSM1012779             Supplementary_files_format_and_content: File a...
# GSM1012780             Supplementary_files_format_and_content: File a...
# GSM1012781             Supplementary_files_format_and_content: File a...
#
# !Sample_geo_accession Sample_platform_id Sample_contact_name  \
# GSM1012777                      GPL13112       Rahul,,Satija
# GSM1012778                      GPL13112       Rahul,,Satija
# GSM1012779                      GPL13112       Rahul,,Satija
# GSM1012780                      GPL13112       Rahul,,Satija
# GSM1012781                      GPL13112       Rahul,,Satija
#
# !Sample_geo_accession  Sample_contact_email Sample_contact_phone  \
# GSM1012777             rsatija@nygenome.org           6177022468
# GSM1012778             rsatija@nygenome.org           6177022468
# GSM1012779             rsatija@nygenome.org           6177022468
# GSM1012780             rsatija@nygenome.org           6177022468
# GSM1012781             rsatija@nygenome.org           6177022468
#
# !Sample_geo_accession Sample_contact_laboratory Sample_contact_institute  \
# GSM1012777                           Satija Lab   New York Genome Center
# GSM1012778                           Satija Lab   New York Genome Center
# GSM1012779                           Satija Lab   New York Genome Center
# GSM1012780                           Satija Lab   New York Genome Center
# GSM1012781                           Satija Lab   New York Genome Center
#
# !Sample_geo_accession      Sample_contact_address Sample_contact_city  \
# GSM1012777             101 Avenue of the Americas       New York City
# GSM1012778             101 Avenue of the Americas       New York City
# GSM1012779             101 Avenue of the Americas       New York City
# GSM1012780             101 Avenue of the Americas       New York City
# GSM1012781             101 Avenue of the Americas       New York City
#
# !Sample_geo_accession Sample_contact_state Sample_contact_zip/postal_code  \
# GSM1012777                              NY                          10013
# GSM1012778                              NY                          10013
# GSM1012779                              NY                          10013
# GSM1012780                              NY                          10013
# GSM1012781                              NY                          10013
#
# !Sample_geo_accession Sample_contact_country Sample_data_row_count  \
# GSM1012777                               USA                     0
# GSM1012778                               USA                     0
# GSM1012779                               USA                     0
# GSM1012780                               USA                     0
# GSM1012781                               USA                     0
#
# !Sample_geo_accession Sample_instrument_model Sample_library_selection  \
# GSM1012777                Illumina HiSeq 2000                     cDNA
# GSM1012778                Illumina HiSeq 2000                     cDNA
# GSM1012779                Illumina HiSeq 2000                     cDNA
# GSM1012780                Illumina HiSeq 2000                     cDNA
# GSM1012781                Illumina HiSeq 2000                     cDNA
#
# !Sample_geo_accession Sample_library_source Sample_library_strategy  \
# GSM1012777                   transcriptomic                 RNA-Seq
# GSM1012778                   transcriptomic                 RNA-Seq
# GSM1012779                   transcriptomic                 RNA-Seq
# GSM1012780                   transcriptomic                 RNA-Seq
# GSM1012781                   transcriptomic                 RNA-Seq
#
# !Sample_geo_accession                                    Sample_relation  \
# GSM1012777             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012778             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012779             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012780             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
# GSM1012781             SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX...
#
# !Sample_geo_accession                                    Sample_relation  \
# GSM1012777             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012778             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012779             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012780             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
# GSM1012781             BioSample: https://www.ncbi.nlm.nih.gov/biosam...
#
# !Sample_geo_accession Sample_supplementary_file_1 series_matrix_table_begin  \
# GSM1012777                                   NONE                       NaN
# GSM1012778                                   NONE                       NaN
# GSM1012779                                   NONE                       NaN
# GSM1012780                                   NONE                       NaN
# GSM1012781                                   NONE                       NaN
#
# !Sample_geo_accession      ID_REF series_matrix_table_end
# GSM1012777             GSM1012777                     NaN
# GSM1012778             GSM1012778                     NaN
# GSM1012779             GSM1012779                     NaN
# GSM1012780             GSM1012780                     NaN
# GSM1012781             GSM1012781                     NaN

# %% [markdown]
# ### Okay, now we're ready to do some analysis!
#
# We've looked at the top of the dataframe by using `head()`. By default, this shows the first 5 rows.

# %%
shalek2013_expression.head()
# Out:
#                  S1        S2          S3        S4        S5        S6  \
# GENE
# XKR4       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# AB338584   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# B3GAT2     0.000000  0.000000    0.023441  0.000000  0.000000  0.029378
# NPL       72.008590  0.000000  128.062012  0.095082  0.000000  0.000000
# T2         0.109249  0.172009    0.000000  0.000000  0.182703  0.076012
#
#                   S7          S8        S9       S10       S11       S12  \
# GENE
# XKR4        0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584    0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2      0.000000    0.055452  0.000000  0.029448  0.024137  0.000000
# NPL       112.310234  104.329122  0.119230  0.000000  0.000000  0.000000
# T2          0.078698    0.000000  0.093698  0.076583  0.000000  0.693459
#
#                S13       S14       S15       S16       S17        S18  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# B3GAT2    0.000000  0.031654  0.000000  0.000000  0.000000  42.150208
# NPL       0.116802  0.104200  0.106188  0.229197  0.110582   0.000000
# T2        0.010137  0.081936  0.000000  0.000000  0.086879   0.068174
#
#                 P1        P2         P3
# GENE
# XKR4      0.000000  0.019906   0.000000
# AB338584  0.000000  0.000000   0.000000
# B3GAT2    0.680327  0.022996   0.110236
# NPL       7.109356  6.727028  14.525447
# T2        0.062063  0.000000   0.050605

# %% [markdown]
# To specify a certain number of rows, put a number between the parentheses.

# %%
shalek2013_expression.head(8)
# Out:
#                       S1        S2          S3        S4        S5        S6  \
# GENE
# XKR4            0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# AB338584        0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# B3GAT2          0.000000  0.000000    0.023441  0.000000  0.000000  0.029378
# NPL            72.008590  0.000000  128.062012  0.095082  0.000000  0.000000
# T2              0.109249  0.172009    0.000000  0.000000  0.182703  0.076012
# T               0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# PDE10A          0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 1700010I14RIK   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
#
#                        S7          S8        S9       S10       S11       S12  \
# GENE
# XKR4             0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584         0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2           0.000000    0.055452  0.000000  0.029448  0.024137  0.000000
# NPL            112.310234  104.329122  0.119230  0.000000  0.000000  0.000000
# T2               0.078698    0.000000  0.093698  0.076583  0.000000  0.693459
# T                0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# PDE10A           0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 1700010I14RIK    0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
#
#                     S13       S14       S15       S16       S17        S18  \
# GENE
# XKR4           0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# AB338584       0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# B3GAT2         0.000000  0.031654  0.000000  0.000000  0.000000  42.150208
# NPL            0.116802  0.104200  0.106188  0.229197  0.110582   0.000000
# T2             0.010137  0.081936  0.000000  0.000000  0.086879   0.068174
# T              0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# PDE10A         0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 1700010I14RIK  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#                      P1        P2         P3
# GENE
# XKR4           0.000000  0.019906   0.000000
# AB338584       0.000000  0.000000   0.000000
# B3GAT2         0.680327  0.022996   0.110236
# NPL            7.109356  6.727028  14.525447
# T2             0.062063  0.000000   0.050605
# T              0.000000  0.000000   0.000000
# PDE10A         0.000000  0.018610   0.011152
# 1700010I14RIK  0.806956  0.000000   0.000000

# %% [markdown]
# Let's get a sense of this data by plotting the distributions using `boxplot` from seaborn. To save the output, we'll need to get access to the current figure, and save this to a variable using `plt.gcf()`. And then we'll save this figure with `fig.savefig("filename.pdf")`. You can use other extensions (e.g. "`.png`", "`.tiff`" and it'll automatically save as that forma)

# %%
sns.boxplot(shalek2013_expression['S1'])

# gcf = Get current figure
fig = plt.gcf()
fig.savefig('shalek2013_expression_boxplot.pdf')

# %% [markdown]
# Notice the 140,000 maximum ... Oh right we have expression data and the scales are enormous... Let's add 1 to all values and take the log2 of the data. We add one because log(0) is undefined and then all our logged values start from zero too. This "$\log_2(TPM + 1)$" is a very common transformation of expression data so it's easier to analyze.

# %%
expression_logged = np.log2(shalek2013_expression+1)
expression_logged.head()
# Out:
#                 S1        S2        S3        S4        S5        S6  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.000000  0.033427  0.000000  0.000000  0.041774
# NPL       6.189994  0.000000  7.011921  0.131039  0.000000  0.000000
# T2        0.149583  0.228984  0.000000  0.000000  0.242088  0.105695
#
#                 S7        S8        S9       S10       S11       S12  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.077861  0.000000  0.041871  0.034409  0.000000
# NPL       6.824134  6.718761  0.162507  0.000000  0.000000  0.000000
# T2        0.109290  0.000000  0.129215  0.106459  0.000000  0.759973
#
#                S13       S14       S15       S16       S17       S18  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.044960  0.000000  0.000000  0.000000  5.431296
# NPL       0.159374  0.143002  0.145597  0.297716  0.151316  0.000000
# T2        0.014551  0.113616  0.000000  0.000000  0.120192  0.095146
#
#                 P1        P2        P3
# GENE
# XKR4      0.000000  0.028436  0.000000
# AB338584  0.000000  0.000000  0.000000
# B3GAT2    0.748742  0.032801  0.150866
# NPL       3.019587  2.949914  3.956563
# T2        0.086869  0.000000  0.071221

# %%
sns.boxplot(x=expression_logged['S1'])

# gcf = Get current figure
#fig = plt.gcf()
#fig.savefig('expression_logged_boxplot.pdf')

# %% [markdown]
# ## Filtering expression data
#
# Seems like a lot of genes are near zero, which means we need to filter our genes.
#
# We can ask which genes have log2 expression values are less than 2 (weird example I know - stay with me). This creates a dataframe of `boolean` values of True/False.

# %%
at_most_2 = expression_logged < 2
at_most_2
# Out:
#              S1     S2     S3     S4     S5     S6     S7     S8     S9  \
# GENE
# XKR4       True   True   True   True   True   True   True   True   True
# AB338584   True   True   True   True   True   True   True   True   True
# B3GAT2     True   True   True   True   True   True   True   True   True
# NPL       False   True  False   True   True   True  False  False   True
# T2         True   True   True   True   True   True   True   True   True
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# BRP44L    False  False  False  False  False  False  False  False  False
# AK014435   True   True   True   True   True   True   True   True   True
# AK015714   True   True   True   True   True   True   True   True   True
# SFT2D1    False  False   True   True  False   True  False  False  False
# PRR18      True   True   True   True   True   True   True   True   True
#
#             S10    S11    S12    S13    S14    S15    S16    S17    S18  \
# GENE
# XKR4       True   True   True   True   True   True   True   True   True
# AB338584   True   True   True   True   True   True   True   True   True
# B3GAT2     True   True   True   True   True   True   True   True  False
# NPL        True   True   True   True   True   True   True   True   True
# T2         True   True   True   True   True   True   True   True   True
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# BRP44L    False  False  False  False  False  False  False  False  False
# AK014435   True   True   True   True   True   True   True   True   True
# AK015714   True   True   True   True  False   True   True   True   True
# SFT2D1     True   True   True  False   True   True   True  False  False
# PRR18      True   True   True   True   True   True   True   True   True
#
#              P1     P2     P3
# GENE
# XKR4       True   True   True
# AB338584   True   True   True
# B3GAT2     True   True   True
# NPL       False  False  False
# T2         True   True   True
# ...         ...    ...    ...
# BRP44L    False  False  False
# AK014435   True   True   True
# AK015714   True   True   True
# SFT2D1    False  False  False
# PRR18      True   True   True
#
# [27723 rows x 21 columns]

# %% [markdown]
# What's nice about booleans is that False is 0 and True is 1, so we can sum to get the number of "Trues." This is a simple, clever way that we can filter on a count for the data. We **could** use this boolean dataframe to filter our original dataframe, but then we lose information. For all values that are greater than 2, it puts in a "not a number" - "NaN."

# %%
expression_at_most_2 = expression_logged[expression_logged < 2]
print(expression_at_most_2.shape)
expression_at_most_2.head()
# Out:
# (27723, 21)
#                 S1        S2        S3        S4        S5        S6       S7  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# B3GAT2    0.000000  0.000000  0.033427  0.000000  0.000000  0.041774  0.00000
# NPL            NaN  0.000000       NaN  0.131039  0.000000  0.000000      NaN
# T2        0.149583  0.228984  0.000000  0.000000  0.242088  0.105695  0.10929
#
#                 S8        S9       S10       S11       S12       S13  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.077861  0.000000  0.041871  0.034409  0.000000  0.000000
# NPL            NaN  0.162507  0.000000  0.000000  0.000000  0.159374
# T2        0.000000  0.129215  0.106459  0.000000  0.759973  0.014551
#
#                S14       S15       S16       S17       S18        P1  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.044960  0.000000  0.000000  0.000000       NaN  0.748742
# NPL       0.143002  0.145597  0.297716  0.151316  0.000000       NaN
# T2        0.113616  0.000000  0.000000  0.120192  0.095146  0.086869
#
#                 P2        P3
# GENE
# XKR4      0.028436  0.000000
# AB338584  0.000000  0.000000
# B3GAT2    0.032801  0.150866
# NPL            NaN       NaN
# T2        0.000000  0.071221

# %% [markdown]
# ### Exercise 4: Crude filtering on expression data
#
# Create a dataframe called "`expression_greater_than_5`" which contains only values that are greater than 5 from `expression_logged`.

# %%
expression_logged.head()
# Out:
#                 S1        S2        S3        S4        S5        S6  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.000000  0.033427  0.000000  0.000000  0.041774
# NPL       6.189994  0.000000  7.011921  0.131039  0.000000  0.000000
# T2        0.149583  0.228984  0.000000  0.000000  0.242088  0.105695
#
#                 S7        S8        S9       S10       S11       S12  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.077861  0.000000  0.041871  0.034409  0.000000
# NPL       6.824134  6.718761  0.162507  0.000000  0.000000  0.000000
# T2        0.109290  0.000000  0.129215  0.106459  0.000000  0.759973
#
#                S13       S14       S15       S16       S17       S18  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.044960  0.000000  0.000000  0.000000  5.431296
# NPL       0.159374  0.143002  0.145597  0.297716  0.151316  0.000000
# T2        0.014551  0.113616  0.000000  0.000000  0.120192  0.095146
#
#                 P1        P2        P3
# GENE
# XKR4      0.000000  0.028436  0.000000
# AB338584  0.000000  0.000000  0.000000
# B3GAT2    0.748742  0.032801  0.150866
# NPL       3.019587  2.949914  3.956563
# T2        0.086869  0.000000  0.071221

# %%
expression_greater_than_5 = expression_logged[expression_logged > 5]
expression_greater_than_5.head()
# Out:
#                 S1  S2        S3  S4  S5  S6        S7        S8  S9  S10  \
# GENE
# XKR4           NaN NaN       NaN NaN NaN NaN       NaN       NaN NaN  NaN
# AB338584       NaN NaN       NaN NaN NaN NaN       NaN       NaN NaN  NaN
# B3GAT2         NaN NaN       NaN NaN NaN NaN       NaN       NaN NaN  NaN
# NPL       6.189994 NaN  7.011921 NaN NaN NaN  6.824134  6.718761 NaN  NaN
# T2             NaN NaN       NaN NaN NaN NaN       NaN       NaN NaN  NaN
#
#           S11  S12  S13  S14  S15  S16  S17       S18  P1  P2  P3
# GENE
# XKR4      NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN NaN NaN NaN
# AB338584  NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN NaN NaN NaN
# B3GAT2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  5.431296 NaN NaN NaN
# NPL       NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN NaN NaN NaN
# T2        NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN NaN NaN NaN

# %% [markdown]
# The crude filtering above is okay, but we're smarter than that. We want to use the filtering in the paper:
#
# > *... discarded genes that were not appreciably expressed (transcripts per million (TPM) > 1) in at least three individual cells, retaining 6,313 genes for further analysis.*
#
# We want to do THAT, but first we need a couple more concepts. The first one is summing booleans.
#
# ## A smarter way to filter
#
# Remember that booleans are really 0s (`False`) and 1s (`True`)? This turns out to be VERY convenient and we can use this concept in clever ways.
#
# We can use `.sum()` on a boolean matrix to get the number of genes with expression greater than 10 for each sample:

# %%
(expression_logged > 10).sum()
# Out:
# S1     136
# S2     174
# S3     142
# S4     135
# S5     134
# S6     144
# S7     145
# S8     124
# S9     171
# S10    135
# S11    132
# S12    129
# S13    133
# S14    139
# S15    157
# S16    147
# S17    119
# S18    152
# P1     136
# P2     136
# P3     140
# dtype: int64

# %% [markdown]
# `pandas` is column-oriented and by default, it will give you a sum for each column. But **we** want a sum for each row. How do we do that?
#
#
# We can sum the boolean matrix we created with "`expression_logged < 10`" along `axis=1` (along the samples) to get **for each gene, how many samples have expression less than 10**. In `pandas`, this column is called a "`Series`" because it has only one dimension - its length. Internally, `pandas` stores dataframes as a bunch of columns - specifically these `Series`ssssss.
#
# This turns out to be not that many.

# %%
(expression_logged > 10).sum(axis=1)
# Out:
# GENE
# XKR4        0
# AB338584    0
# B3GAT2      0
# NPL         0
# T2          0
#            ..
# BRP44L      9
# AK014435    0
# AK015714    0
# SFT2D1      0
# PRR18       0
# Length: 27723, dtype: int64

# %% [markdown]
# Now we can apply ANOTHER filter and find genes that are "present" (expression greater than 10) in at least 5 samples. We'll save this as the variable `genes_of_interest`. Notice that this doesn't the `genes_of_interest` but rather the list at the bottom. This is because what you see under a code cell is the output of the last thing you called. The "hash mark"/"number sign" "`#`" is called a **comment character** and makes the rest of the line after it not read by the Python language.
#
# ### Exercise 5: Commenting and uncommenting
#
# To see `genes_of_interest`, "uncomment" the line by removing the hash sign, and commenting out the list `[1, 2, 3]`.

# %%
genes_of_interest = (expression_logged > 10).sum(axis=1) >= 5
#genes_of_interest
[1, 2, 3]
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Getting only rows that you want (aka subsetting)
#
# Now we have some genes that we want to use - how do you pick just those? This can also be called "subsetting" and in `pandas` has the technical name [indexing](http://pandas.pydata.org/pandas-docs/stable/indexing.html)
#
# In `pandas`, to get the rows (genes) you want using their name (gene symbol) or boolean matrix, you use `.loc[rows_you_want]`. Check it out below.

# %%
expression_filtered = expression_logged.loc[genes_of_interest]
print(expression_filtered.shape)  # shows (nrows, ncols) - like in manhattan you do the Street then the Avenue
expression_filtered.head()
# Out:
# (197, 21)
#                 S1         S2         S3         S4         S5         S6  \
# GENE
# ATP6V0C   9.745346  10.338442   9.705273   9.851411  11.210533  11.314901
# ATP6V0E   9.759254  10.803245  10.525163  10.785315  10.075346  10.638548
# ATPASE6  12.719591  12.347896  13.192752  12.893249  12.819598  13.085962
# RPS18    10.080293  10.954047  10.065784   8.589813   9.639211  10.413408
# H2-K1     7.995149   7.052728   7.107182   8.214478   7.097269   9.097707
#
#                 S7         S8         S9        S10        S11        S12  \
# GENE
# ATP6V0C  10.506642  10.508520  10.975713  10.603084  10.583834   3.714740
# ATP6V0E  10.359707  10.014628   9.771179  10.574154   8.040055  10.959248
# ATPASE6  13.277271  13.113396  12.628063  12.661354  11.975493  13.222727
# RPS18    10.894525   9.841402  11.569947  10.433555  10.211308  11.444838
# H2-K1     9.356559   8.312146   2.383879   7.684320   9.353743  11.932448
#
#                S13        S14        S15        S16        S17        S18  \
# GENE
# ATP6V0C   9.035086   9.905386  11.289761   9.590110  11.709422  10.520829
# ATP6V0E  10.990677  11.049803  10.703815  10.301053   9.191934  10.591682
# ATPASE6  13.251932  13.156902  12.800159  13.209035  12.882030  13.395213
# RPS18    11.041503   9.424527   9.254507  11.392399  10.085782  10.075320
# H2-K1    10.292641   8.874284   7.708732   9.783448   6.708027   6.825463
#
#                 P1         P2         P3
# GENE
# ATP6V0C  10.723323  10.598279  10.698255
# ATP6V0E  10.037123  10.148096  10.028377
# ATPASE6  12.503962  12.461228  12.450822
# RPS18    10.290437  10.274727  10.370112
# H2-K1    10.152567  10.192475  10.200949

# %% [markdown]
# Wow, our matrix is very small - 197 genes! We probably don't want to filter THAT much... I'd say a range of 5,000-15,000 genes after filtering is a good ballpark. Not too big so it's impossible to work with but not too small that you can't do any statistics.
#
# We'll get closer to the expression data created by the paper. Remember that they filtered on genes that had expression greater than 1 in at least 3 *single cells*. We'll filter for expression greater than 1 in at least 3 *samples* for now - we'll get to the single stuff in a bit. For now, we'll filter on all samples.
#
# ### Exercise: Filtering on the presence of genes
#
# Create a dataframe called `expression_filtered_by_all_samples` that consists only of genes that have expression greater than 1 in at least 3 samples.
#
# #### Hint for `IndexingError: Unalignable boolean Series key provided`
#
# If you're getting this error, double-check your `.sum()` command. Did you remember to specify that you want to get the number of cells (columns) that express each **gene** (row)? Remember that `.sum()` by default gives you the sum over columns, but since genes are the rows .... How do you get the sum over rows?

# %%
genes_of_interest = (expression_logged > 1).sum(axis=1) >= 3

expression_filtered_by_all_samples = expression_logged.loc[genes_of_interest]
print(expression_filtered_by_all_samples.shape)
expression_filtered_by_all_samples.head()
# Out:
# (9943, 21)
#                 S1        S2        S3        S4        S5        S6  \
# GENE
# NPL       6.189994  0.000000  7.011921  0.131039  0.000000  0.000000
# QK        7.268986  6.035328  5.551280  0.096368  4.769427  0.164792
# AK163153  1.802450  2.809825  1.561663  1.615288  1.828564  1.301057
# PARK2     0.780057  0.721962  0.871528  0.604061  0.000000  0.867463
# AGPAT4    0.137159  8.466538  5.968792  0.095240  0.000000  6.852955
#
#                 S7        S8        S9       S10       S11       S12  \
# GENE
# NPL       6.824134  6.718761  0.162507  0.000000  0.000000  0.000000
# QK        5.381642  3.967559  0.193883  1.096957  0.952657  0.000000
# AK163153  1.490883  1.411808  1.761127  1.493531  1.156065  3.509926
# PARK2     0.584193  0.797628  0.495236  1.217808  0.691142  2.325056
# AGPAT4    0.100044  5.959222  4.802383  0.000000  7.381994  0.000000
#
#                S13       S14       S15       S16       S17       S18  \
# GENE
# NPL       0.159374  0.143002  0.145597  0.297716  0.151316  0.000000
# QK        4.899227  3.310201  0.434425  5.118232  3.153489  0.059040
# AK163153  3.034182  1.602128  1.734510  6.415105  1.972540  0.617935
# PARK2     1.089339  1.600526  1.165026  0.846808  0.699883  0.131962
# AGPAT4    0.000000  6.392022  0.000000  0.000000  6.086903  0.246741
#
#                 P1        P2        P3
# GENE
# NPL       3.019587  2.949914  3.956563
# QK        5.581934  5.324961  5.297343
# AK163153  0.872966  0.566249  0.411154
# PARK2     1.176145  0.385246  0.931065
# AGPAT4    4.117659  3.086869  4.048623

# %% [markdown]
# Just for fun, let's see how our the distributions in our expression matrix have changed. If you want to save the figure, you can:

# %%
sns.boxplot(expression_filtered_by_all_samples)

# gcf = Get current figure
fig = plt.gcf()
fig.savefig('expression_filtered_by_all_samples_boxplot.pdf')

# %% [markdown]
# ## Getting only the columns you want
#
# In the next exercise, we'll get just the single cells
#
# For the next step, we're going to pull out just the pooled - which are conveniently labeled as "P#". We'll do this using a [list comprehension](http://www.pythonforbeginners.com/basics/list-comprehensions-in-python), which means we'll create a new list based on the items in `shalek2013_expression.columns` and whether or not they start with the letter `'P'`.
#
# In Python, things in square brackets (`[]`) are lists unless indicated otherwise. We are using a list comprehension here instead of a map, because we only want a *subset* of the columns, rather than *all* of them.

# %%
pooled_ids = [x for x in expression_logged.columns if x.startswith('P')]
pooled_ids
# Out:
# ['P1', 'P2', 'P3']

# %% [markdown]
# We'll access the columns we want using this bracket notation (note that this only works for columns, not rows)

# %%
pooled = expression_logged[pooled_ids]
pooled.head()
# Out:
#                 P1        P2        P3
# GENE
# XKR4      0.000000  0.028436  0.000000
# AB338584  0.000000  0.000000  0.000000
# B3GAT2    0.748742  0.032801  0.150866
# NPL       3.019587  2.949914  3.956563
# T2        0.086869  0.000000  0.071221

# %% [markdown]
# We could do the same thing using `.loc` but we would need to put a colon "`:`" in the "rows" section (first place) to show that we want "all rows."

# %%
expression_logged.loc[:, pooled_ids].head()
# Out:
#                 P1        P2        P3
# GENE
# XKR4      0.000000  0.028436  0.000000
# AB338584  0.000000  0.000000  0.000000
# B3GAT2    0.748742  0.032801  0.150866
# NPL       3.019587  2.949914  3.956563
# T2        0.086869  0.000000  0.071221

# %% [markdown]
# ### Exercise: Make a dataframe of only single samples
#
# Use list comprehensions to make a list called `single_ids` that consists only of single cells, and use that list to subset `expression_logged` and create a dataframe called `singles`. (Hint - how are the single cells ids different from the pooled ids?)

# %%
single_ids = [x for x in expression_logged.columns if x.startswith('S')]
singles = expression_logged[single_ids]
print(singles.shape)
singles.head()
# Out:
# (27723, 18)
#                 S1        S2        S3        S4        S5        S6  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.000000  0.033427  0.000000  0.000000  0.041774
# NPL       6.189994  0.000000  7.011921  0.131039  0.000000  0.000000
# T2        0.149583  0.228984  0.000000  0.000000  0.242088  0.105695
#
#                 S7        S8        S9       S10       S11       S12  \
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.077861  0.000000  0.041871  0.034409  0.000000
# NPL       6.824134  6.718761  0.162507  0.000000  0.000000  0.000000
# T2        0.109290  0.000000  0.129215  0.106459  0.000000  0.759973
#
#                S13       S14       S15       S16       S17       S18
# GENE
# XKR4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# AB338584  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# B3GAT2    0.000000  0.044960  0.000000  0.000000  0.000000  5.431296
# NPL       0.159374  0.143002  0.145597  0.297716  0.151316  0.000000
# T2        0.014551  0.113616  0.000000  0.000000  0.120192  0.095146

# %% [markdown]
# ## Using two different dataframes for filtering
#
# ### Exercise 8: Filter the full dataframe using the singles dataframe
#
# Now we'll actually do the filtering done by the paper. Using the `singles` dataframe you just created, get the genes that have expression greater than 1 in at least 3 single cells, and use that to filter `expression_logged`. Call this dataframe `expression_filtered_by_singles`.

# %%
rows = (singles > 1).sum(axis=1) > 3

expression_filtered_by_singles = expression_logged.loc[rows]
print(expression_filtered_by_singles.shape)
expression_filtered_by_singles.head()
# Out:
# (5346, 21)
#                 S1        S2        S3        S4        S5        S6  \
# GENE
# NPL       6.189994  0.000000  7.011921  0.131039  0.000000  0.000000
# QK        7.268986  6.035328  5.551280  0.096368  4.769427  0.164792
# AK163153  1.802450  2.809825  1.561663  1.615288  1.828564  1.301057
# PARK2     0.780057  0.721962  0.871528  0.604061  0.000000  0.867463
# AGPAT4    0.137159  8.466538  5.968792  0.095240  0.000000  6.852955
#
#                 S7        S8        S9       S10       S11       S12  \
# GENE
# NPL       6.824134  6.718761  0.162507  0.000000  0.000000  0.000000
# QK        5.381642  3.967559  0.193883  1.096957  0.952657  0.000000
# AK163153  1.490883  1.411808  1.761127  1.493531  1.156065  3.509926
# PARK2     0.584193  0.797628  0.495236  1.217808  0.691142  2.325056
# AGPAT4    0.100044  5.959222  4.802383  0.000000  7.381994  0.000000
#
#                S13       S14       S15       S16       S17       S18  \
# GENE
# NPL       0.159374  0.143002  0.145597  0.297716  0.151316  0.000000
# QK        4.899227  3.310201  0.434425  5.118232  3.153489  0.059040
# AK163153  3.034182  1.602128  1.734510  6.415105  1.972540  0.617935
# PARK2     1.089339  1.600526  1.165026  0.846808  0.699883  0.131962
# AGPAT4    0.000000  6.392022  0.000000  0.000000  6.086903  0.246741
#
#                 P1        P2        P3
# GENE
# NPL       3.019587  2.949914  3.956563
# QK        5.581934  5.324961  5.297343
# AK163153  0.872966  0.566249  0.411154
# PARK2     1.176145  0.385246  0.931065
# AGPAT4    4.117659  3.086869  4.048623

# %% [markdown]
# Let's make a boxplot again to see how the data has changed.

# %%
sns.boxplot(expression_filtered_by_singles)

fig = plt.gcf()
fig.savefig('expression_filtered_by_singles_boxplot.pdf')

# %% [markdown]
# This is much nicer because now we don't have so many zeros and each sample has a reasonable dynamic range.
#
# ## Why did this filtering even matter?
#
# You may be wondering, we did all this work to remove some zeros..... so the FPKM what? Let's take a look at how this affects the relationships between samples using `sns.jointplot` from seaborn, which will plot a correlation scatterplot. This also calculates the [Pearson correlation](https://en.wikipedia.org/wiki/Pearson_product-moment_correlation_coefficient), a linear correlation metric.
#
# Let's first do this on the unlogged data.

# %%
sns.jointplot(shalek2013_expression['S1'], shalek2013_expression['S2'])

# %% [markdown]
# Pretty funky looking huh? That's why we logged it :)
#
# Now let's try this on the logged data.

# %%
sns.jointplot(expression_logged['S1'], expression_logged['S2'])

# %% [markdown]
# Hmm our pearson correlation increased from 0.62 to 0.64. Why could that be?
#
# Let's look at this same plot using the filtered data.

# %%
sns.jointplot(expression_filtered_by_singles['S1'], expression_filtered_by_singles['S2'])
